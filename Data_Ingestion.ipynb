# %% [markdown]
# # **Data Engineering for ETL: Data Ingestion**

# %% [markdown]
# ## **What is data ingestion?**
# Data ingestion is the process of **extracting** data from a source, transporting it to a suitable environment, and preparing it for use. This often includes **normalizing**, **cleaning**, and **adding metadata**.

# %% [markdown]
# 💡 **What is a schema?**
# A schema defines the expected format and structure of data, including field names, data types, and relationships.

# %% [markdown]
# ---
#
# #### **3. When to use Batch vs. Streaming**
#
# | **Factor**        | **Batch processing**  | **Streaming processing** |
# |------------------|------------------|-------------------|
# | **Latency**      | High (minutes, hours) | Low (milliseconds, seconds) |
# | **Data volume**  | Large batches | Continuous small events |
# | **Use case**     | Reports, ETL, backups | Real-time analytics, event-driven apps |
# | **Complexity**   | Easier to manage | Requires event-driven architecture |
# | **Cost**         | Lower for periodic runs | Higher for always-on processing |

# %% [markdown]
# There are some limits in API:
#
# 1. **Hardware limits**: Be mindful of memory (RAM) and storage (disk space). Overloading these can crash your system.
# 2. **Network reliability**: Networks can fail! Always account for retries to make your pipelines more robust.
#    - Tip: Use libraries like `dlt` that have built-in retry mechanisms.
# 3. **API rate limits**: APIs often restrict the number of requests you can make in a given time.
#    - Tip: Check the API documentation to understand its limits (e.g., [Zendesk](https://developer.zendesk.com/api-reference/introduction/rate-limits/), [Shopify](https://shopify.dev/docs/api/usage/rate-limits)).
#
# There are even more challenges to consider when working with APIs — such as **pagination and authentication**. Let’s explore how to handle these effectively when working with **REST APIs**.

# %%
import requests

result = requests.get("https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events").json()
print(result)
# Out:
# [{'id': '52054879166', 'type': 'WatchEvent', 'actor': {'id': 212767187, 'login': 'reyaleman-tech', 'display_login': 'reyaleman-tech', 'gravatar_id': '', 'url': 'https://api.github.com/users/reyaleman-tech', 'avatar_url': 'https://avatars.githubusercontent.com/u/212767187?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-14T12:25:55Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52051650046', 'type': 'ForkEvent', 'actor': {'id': 91944358, 'login': 'qkrwnscjf', 'display_login': 'qkrwnscjf', 'gravatar_id': '', 'url': 'https://api.github.com/users/qkrwnscjf', 'avatar_url': 'https://avatars.githubusercontent.com/u/91944358?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1019462765, 'node_id': 'R_kgDOPMPEbQ', 'name': 'data-engineering-zoomcamp', 'full_name': 'qkrwnscjf/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'qkrwnscjf', 'id': 91944358, 'node_id': 'U_kgDOBXr1pg', 'avatar_url': 'https://avatars.githubusercontent.com/u/91944358?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/qkrwnscjf', 'html_url': 'https://github.com/qkrwnscjf', 'followers_url': 'https://api.github.com/users/qkrwnscjf/followers', 'following_url': 'https://api.github.com/users/qkrwnscjf/following{/other_user}', 'gists_url': 'https://api.github.com/users/qkrwnscjf/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/qkrwnscjf/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/qkrwnscjf/subscriptions', 'organizations_url': 'https://api.github.com/users/qkrwnscjf/orgs', 'repos_url': 'https://api.github.com/users/qkrwnscjf/repos', 'events_url': 'https://api.github.com/users/qkrwnscjf/events{/privacy}', 'received_events_url': 'https://api.github.com/users/qkrwnscjf/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/qkrwnscjf/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp ...

# %% [markdown]
# #### **Common Challenges**

# %% [markdown]
# #### **1. Rate limits**
#
# To avoid hitting these limits, we can:
# - **Monitor API rate limits** – Some APIs provide headers that tell you how many requests you have left.
# - **Pause requests when needed** – If we're close to the limit, we wait before making more requests.
# - **Implement automatic retries** – If a request fails due to rate limiting, we can wait and retry after some time.
#
# Some APIs provide a **retry-after** header, which tells you how long to wait before making another request. Always check the API documentation for best practices!

# %%
import time
import requests


response = requests.get("https://api.github.com/rate_limit")
rate_limit = response.json()["rate"]["remaining"]
print("The rate limit remains: ", rate_limit)

if rate_limit == 0:
    time.sleep(60)  # Wait before making more requests
# Out:
# The rate limit remains:  60

# %% [markdown]
# ---
#
# #### **2. Authentication**
# Many APIs require an **API key or token** to access data securely. Without authentication, requests may be limited or denied.
#
# **Types of Authentication in APIs:**
# - **API Keys** – A simple token included in the request header or URL.
# - **OAuth Tokens** – A more secure authentication method requiring user authorization.
# - **Basic Authentication** – Using a username and password (less common today).

# %%
import os
import requests
from google.colab import userdata

API_TOKEN = userdata.get('ACCESS_TOKEN')


headers = {"Authorization": f"Bearer {API_TOKEN}"}
response = requests.get("https://api.github.com/user", headers=headers)
print(response.json())
# Out:
# {'login': 'vedantparmar12', 'id': 122482472, 'node_id': 'U_kgDOB0zvKA', 'avatar_url': 'https://avatars.githubusercontent.com/u/122482472?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/vedantparmar12', 'html_url': 'https://github.com/vedantparmar12', 'followers_url': 'https://api.github.com/users/vedantparmar12/followers', 'following_url': 'https://api.github.com/users/vedantparmar12/following{/other_user}', 'gists_url': 'https://api.github.com/users/vedantparmar12/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/vedantparmar12/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/vedantparmar12/subscriptions', 'organizations_url': 'https://api.github.com/users/vedantparmar12/orgs', 'repos_url': 'https://api.github.com/users/vedantparmar12/repos', 'events_url': 'https://api.github.com/users/vedantparmar12/events{/privacy}', 'received_events_url': 'https://api.github.com/users/vedantparmar12/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'name': 'Vedant', 'company': None, 'blog': '', 'location': None, 'email': None, 'hireable': None, 'bio': None, 'twitter_username': None, 'notification_email': None, 'public_repos': 91, 'public_gists': 1, 'followers': 0, 'following': 5, 'created_at': '2023-01-11T19:13:46Z', 'updated_at': '2025-06-18T08:37:32Z'}

# %% [markdown]
# ----
# #### **3. Pagination**
#
# Many APIs return data in **chunks (or pages)** rather than sending everything at once. This prevents **overloading the server** and improves performance, especially for large datasets. To retrieve **all the data**, we need to make multiple requests and keep track of pages until we reach the last one.

# %%
import requests
from google.colab import userdata

API_TOKEN = userdata.get('ACCESS_TOKEN')
BASE_URL = "https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events"


page_number = 1

while True:
    response = requests.get(BASE_URL, headers={"Authorization": f"Bearer {API_TOKEN}"})
    page_data = response.json()

    next_page = response.links.get("next", {}).get("url")

    print(f'Got page {page_number} with {len(page_data)} records')
    print(page_data)

    if not next_page:
        break

    page_number += 1
    BASE_URL = next_page
# Out:
# Got page 1 with 30 records
# [{'id': '52054879166', 'type': 'WatchEvent', 'actor': {'id': 212767187, 'login': 'reyaleman-tech', 'display_login': 'reyaleman-tech', 'gravatar_id': '', 'url': 'https://api.github.com/users/reyaleman-tech', 'avatar_url': 'https://avatars.githubusercontent.com/u/212767187?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-14T12:25:55Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52051650046', 'type': 'ForkEvent', 'actor': {'id': 91944358, 'login': 'qkrwnscjf', 'display_login': 'qkrwnscjf', 'gravatar_id': '', 'url': 'https://api.github.com/users/qkrwnscjf', 'avatar_url': 'https://avatars.githubusercontent.com/u/91944358?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1019462765, 'node_id': 'R_kgDOPMPEbQ', 'name': 'data-engineering-zoomcamp', 'full_name': 'qkrwnscjf/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'qkrwnscjf', 'id': 91944358, 'node_id': 'U_kgDOBXr1pg', 'avatar_url': 'https://avatars.githubusercontent.com/u/91944358?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/qkrwnscjf', 'html_url': 'https://github.com/qkrwnscjf', 'followers_url': 'https://api.github.com/users/qkrwnscjf/followers', 'following_url': 'https://api.github.com/users/qkrwnscjf/following{/other_user}', 'gists_url': 'https://api.github.com/users/qkrwnscjf/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/qkrwnscjf/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/qkrwnscjf/subscriptions', 'organizations_url': 'https://api.github.com/users/qkrwnscjf/orgs', 'repos_url': 'https://api.github.com/users/qkrwnscjf/repos', 'events_url': 'https://api.github.com/users/qkrwnscjf/events{/privacy}', 'received_events_url': 'https://api.github.com/users/qkrwnscjf/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/qkrwnscjf/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp ...
# Got page 2 with 30 records
# [{'id': '52014996769', 'type': 'WatchEvent', 'actor': {'id': 170357317, 'login': 'BrunoChiconato', 'display_login': 'BrunoChiconato', 'gravatar_id': '', 'url': 'https://api.github.com/users/BrunoChiconato', 'avatar_url': 'https://avatars.githubusercontent.com/u/170357317?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-13T01:17:15Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52014749536', 'type': 'WatchEvent', 'actor': {'id': 103594543, 'login': 'bautivizioli', 'display_login': 'bautivizioli', 'gravatar_id': '', 'url': 'https://api.github.com/users/bautivizioli', 'avatar_url': 'https://avatars.githubusercontent.com/u/103594543?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-13T00:52:15Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52013277236', 'type': 'WatchEvent', 'actor': {'id': 137610184, 'login': 'ryan-tilley', 'display_login': 'ryan-tilley', 'gravatar_id': '', 'url': 'https://api.github.com/users/ryan-tilley', 'avatar_url': 'https://avatars.githubusercontent.com/u/137610184?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-12T22:22:04Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52013032439', 'type': 'WatchEvent', 'actor': {'id': 15807184, 'login': 'NicolNonga', 'display_login': 'NicolNonga', 'gravatar_id': '', 'url': 'https://api.github.com/users/NicolNonga', 'avatar_url': 'https://avatars.githubusercontent.com/u/15807184?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-12T21:59:54Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52012296833', 'type': 'ForkEvent', 'actor': {'id': 86207070, 'login': 'seunshix', 'display_login': 'seunshix', 'gravatar_id': '', 'url': 'https://api.github.com/users/seunshix', 'avatar_url': 'https://avatars.githubusercontent.com/u/86207070?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1018699766, 'node_id': 'R_kgDOPLgf9g', 'name': 'data-engineering-zoomcamp', 'full_name': 'seunshix/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'seunshix', 'id': 86207070, 'node_id': 'MDQ6VXNlcjg2MjA3MDcw', 'avatar_url': 'https://avatars.githubusercontent.com/u/86207070?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/seunshix', 'html_url': 'https://github.com/seunshix', 'followers_url': 'https://api.github.com/users/seunshix/followers', 'following_url': 'https://api.github.com/users/seunshix/following{/other_user}', 'gists_url': 'https://api.github.com/users/seunshix/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/seunshix/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.co ...
# Got page 3 with 30 records
# [{'id': '51992777459', 'type': 'WatchEvent', 'actor': {'id': 121058317, 'login': '1-turbo', 'display_login': '1-turbo', 'gravatar_id': '', 'url': 'https://api.github.com/users/1-turbo', 'avatar_url': 'https://avatars.githubusercontent.com/u/121058317?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-11T20:48:28Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51990471054', 'type': 'WatchEvent', 'actor': {'id': 145046356, 'login': 'Nascfn', 'display_login': 'Nascfn', 'gravatar_id': '', 'url': 'https://api.github.com/users/Nascfn', 'avatar_url': 'https://avatars.githubusercontent.com/u/145046356?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-11T19:30:08Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51988449542', 'type': 'IssueCommentEvent', 'actor': {'id': 39490719, 'login': 'plpcout', 'display_login': 'plpcout', 'gravatar_id': '', 'url': 'https://api.github.com/users/plpcout', 'avatar_url': 'https://avatars.githubusercontent.com/u/39490719?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/727', 'repository_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp', 'labels_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/727/labels{/name}', 'comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/727/comments', 'events_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/727/events', 'html_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/727', 'id': 3037458306, 'node_id': 'PR_kwDOGQOHdM6U06W0', 'number': 727, 'title': 'docs: fix typos', 'user': {'login': 'plpcout', 'id': 39490719, 'node_id': 'MDQ6VXNlcjM5NDkwNzE5', 'avatar_url': 'https://avatars.githubusercontent.com/u/39490719?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/plpcout', 'html_url': 'https://github.com/plpcout', 'followers_url': 'https://api.github.com/users/plpcout/followers', 'following_url': 'https://api.github.com/users/plpcout/following{/other_user}', 'gists_url': 'https://api.github.com/users/plpcout/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/plpcout/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/plpcout/subscriptions', 'organizations_url': 'https://api.github.com/users/plpcout/orgs', 'repos_url': 'https://api.github.com/users/plpcout/repos', 'events_url': 'https://api.github.com/users/plpcout/events{/privacy}', 'received_events_url': 'https://api.github.com/users/plpcout/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'closed', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 2, 'created_at': '2025-05-03T15:09:52Z', 'updated_at': '2025-07-11T18:27:04Z', 'closed_at': '2025-07-10T08:17:42Z', 'author_association': 'CONTRIBUTOR', 'type': None, 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/727', 'html_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/727',  ...
# Got page 4 with 30 records
# [{'id': '51896322464', 'type': 'WatchEvent', 'actor': {'id': 177606441, 'login': 'sykolax', 'display_login': 'sykolax', 'gravatar_id': '', 'url': 'https://api.github.com/users/sykolax', 'avatar_url': 'https://avatars.githubusercontent.com/u/177606441?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-09T20:19:13Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51895868895', 'type': 'WatchEvent', 'actor': {'id': 133255958, 'login': 'geeta-V', 'display_login': 'geeta-V', 'gravatar_id': '', 'url': 'https://api.github.com/users/geeta-V', 'avatar_url': 'https://avatars.githubusercontent.com/u/133255958?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-09T20:05:38Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51891923624', 'type': 'WatchEvent', 'actor': {'id': 182100393, 'login': 'httpmei', 'display_login': 'httpmei', 'gravatar_id': '', 'url': 'https://api.github.com/users/httpmei', 'avatar_url': 'https://avatars.githubusercontent.com/u/182100393?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-09T18:10:42Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51889549884', 'type': 'WatchEvent', 'actor': {'id': 58702367, 'login': 'Rajesh-B-Git', 'display_login': 'Rajesh-B-Git', 'gravatar_id': '', 'url': 'https://api.github.com/users/Rajesh-B-Git', 'avatar_url': 'https://avatars.githubusercontent.com/u/58702367?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-09T17:04:58Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51888295485', 'type': 'ForkEvent', 'actor': {'id': 26826719, 'login': 'arturcast', 'display_login': 'arturcast', 'gravatar_id': '', 'url': 'https://api.github.com/users/arturcast', 'avatar_url': 'https://avatars.githubusercontent.com/u/26826719?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1016861528, 'node_id': 'R_kgDOPJwTWA', 'name': 'data-engineering-zoomcamp', 'full_name': 'arturcast/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'arturcast', 'id': 26826719, 'node_id': 'MDQ6VXNlcjI2ODI2NzE5', 'avatar_url': 'https://avatars.githubusercontent.com/u/26826719?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/arturcast', 'html_url': 'https://github.com/arturcast', 'followers_url': 'https://api.github.com/users/arturcast/followers', 'following_url': 'https://api.github.com/users/arturcast/following{/other_user}', 'gists_url': 'https://api.github.com/users/arturcast/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/arturcast/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/arturcast/subscriptions ...
# Got page 5 with 30 records
# [{'id': '51850066397', 'type': 'WatchEvent', 'actor': {'id': 63064972, 'login': 'Antoni00', 'display_login': 'Antoni00', 'gravatar_id': '', 'url': 'https://api.github.com/users/Antoni00', 'avatar_url': 'https://avatars.githubusercontent.com/u/63064972?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-08T22:16:04Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51849737429', 'type': 'WatchEvent', 'actor': {'id': 77596284, 'login': 'oscar2697', 'display_login': 'oscar2697', 'gravatar_id': '', 'url': 'https://api.github.com/users/oscar2697', 'avatar_url': 'https://avatars.githubusercontent.com/u/77596284?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-08T22:02:45Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51849367823', 'type': 'WatchEvent', 'actor': {'id': 103899744, 'login': 'mlopezgonzalez1105', 'display_login': 'mlopezgonzalez1105', 'gravatar_id': '', 'url': 'https://api.github.com/users/mlopezgonzalez1105', 'avatar_url': 'https://avatars.githubusercontent.com/u/103899744?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-08T21:48:59Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51849177963', 'type': 'WatchEvent', 'actor': {'id': 57726000, 'login': 'joaorty', 'display_login': 'joaorty', 'gravatar_id': '', 'url': 'https://api.github.com/users/joaorty', 'avatar_url': 'https://avatars.githubusercontent.com/u/57726000?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-08T21:41:54Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51848116845', 'type': 'ForkEvent', 'actor': {'id': 85909776, 'login': 'rcarreno90', 'display_login': 'rcarreno90', 'gravatar_id': '', 'url': 'https://api.github.com/users/rcarreno90', 'avatar_url': 'https://avatars.githubusercontent.com/u/85909776?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1016331361, 'node_id': 'R_kgDOPJP8YQ', 'name': 'data-engineering-zoomcamp', 'full_name': 'rcarreno90/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'rcarreno90', 'id': 85909776, 'node_id': 'MDQ6VXNlcjg1OTA5Nzc2', 'avatar_url': 'https://avatars.githubusercontent.com/u/85909776?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rcarreno90', 'html_url': 'https://github.com/rcarreno90', 'followers_url': 'https://api.github.com/users/rcarreno90/followers', 'following_url': 'https://api.github.com/users/rcarreno90/following{/other_user}', 'gists_url': 'https://api.github.com/users/rcarreno90/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rcarreno90/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github ...
# Got page 6 with 30 records
# [{'id': '51799628188', 'type': 'WatchEvent', 'actor': {'id': 70458807, 'login': 'DataWithRyu', 'display_login': 'DataWithRyu', 'gravatar_id': '', 'url': 'https://api.github.com/users/DataWithRyu', 'avatar_url': 'https://avatars.githubusercontent.com/u/70458807?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-07T23:06:41Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51798452520', 'type': 'WatchEvent', 'actor': {'id': 129700252, 'login': 'MARSHALLSROR', 'display_login': 'MARSHALLSROR', 'gravatar_id': '', 'url': 'https://api.github.com/users/MARSHALLSROR', 'avatar_url': 'https://avatars.githubusercontent.com/u/129700252?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-07T22:16:48Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51794729519', 'type': 'WatchEvent', 'actor': {'id': 112006945, 'login': 'EmmaAcquah', 'display_login': 'EmmaAcquah', 'gravatar_id': '', 'url': 'https://api.github.com/users/EmmaAcquah', 'avatar_url': 'https://avatars.githubusercontent.com/u/112006945?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-07T20:13:38Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51789691412', 'type': 'ForkEvent', 'actor': {'id': 178495636, 'login': 's-gunde', 'display_login': 's-gunde', 'gravatar_id': '', 'url': 'https://api.github.com/users/s-gunde', 'avatar_url': 'https://avatars.githubusercontent.com/u/178495636?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1015573125, 'node_id': 'R_kgDOPIhqhQ', 'name': 'data-engineering-zoomcamp', 'full_name': 's-gunde/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 's-gunde', 'id': 178495636, 'node_id': 'U_kgDOCqOglA', 'avatar_url': 'https://avatars.githubusercontent.com/u/178495636?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/s-gunde', 'html_url': 'https://github.com/s-gunde', 'followers_url': 'https://api.github.com/users/s-gunde/followers', 'following_url': 'https://api.github.com/users/s-gunde/following{/other_user}', 'gists_url': 'https://api.github.com/users/s-gunde/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/s-gunde/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/s-gunde/subscriptions', 'organizations_url': 'https://api.github.com/users/s-gunde/orgs', 'repos_url': 'https://api.github.com/users/s-gunde/repos', 'events_url': 'https://api.github.com/users/s-gunde/events{/privacy}', 'received_events_url': 'https://api.github.com/users/s-gunde/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/s-gunde/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/s-gunde/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/s-gunde/data-engineering-zoomcamp ...
# Got page 7 with 30 records
# [{'id': '51735738839', 'type': 'WatchEvent', 'actor': {'id': 96918614, 'login': 'June611', 'display_login': 'June611', 'gravatar_id': '', 'url': 'https://api.github.com/users/June611', 'avatar_url': 'https://avatars.githubusercontent.com/u/96918614?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-06T03:04:20Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51733696242', 'type': 'WatchEvent', 'actor': {'id': 77160481, 'login': 'davramuk', 'display_login': 'davramuk', 'gravatar_id': '', 'url': 'https://api.github.com/users/davramuk', 'avatar_url': 'https://avatars.githubusercontent.com/u/77160481?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-05T23:33:21Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51732841906', 'type': 'WatchEvent', 'actor': {'id': 73328672, 'login': 'matthewwithers', 'display_login': 'matthewwithers', 'gravatar_id': '', 'url': 'https://api.github.com/users/matthewwithers', 'avatar_url': 'https://avatars.githubusercontent.com/u/73328672?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-05T22:06:53Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51732544862', 'type': 'WatchEvent', 'actor': {'id': 71408433, 'login': 'nudwix', 'display_login': 'nudwix', 'gravatar_id': '', 'url': 'https://api.github.com/users/nudwix', 'avatar_url': 'https://avatars.githubusercontent.com/u/71408433?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-05T21:38:27Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51732084728', 'type': 'WatchEvent', 'actor': {'id': 41239149, 'login': 'ymtqyl', 'display_login': 'ymtqyl', 'gravatar_id': '', 'url': 'https://api.github.com/users/ymtqyl', 'avatar_url': 'https://avatars.githubusercontent.com/u/41239149?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-05T20:57:02Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51731218226', 'type': 'WatchEvent', 'actor': {'id': 100478220, 'login': 'yashmittalz', 'display_login': 'yashmittalz', 'gravatar_id': '', 'url': 'https://api.github.com/users/yashmittalz', 'avatar_url': 'https://avatars.githubusercontent.com/u/100478220?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-05T19:40:37Z', 'org': {'id': 72699292, 'login': 'D ...
# Got page 8 with 30 records
# [{'id': '51709392734', 'type': 'WatchEvent', 'actor': {'id': 88166669, 'login': 'benboam', 'display_login': 'benboam', 'gravatar_id': '', 'url': 'https://api.github.com/users/benboam', 'avatar_url': 'https://avatars.githubusercontent.com/u/88166669?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-04T16:40:25Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51708939260', 'type': 'ForkEvent', 'actor': {'id': 217627057, 'login': 'christinaminty', 'display_login': 'christinaminty', 'gravatar_id': '', 'url': 'https://api.github.com/users/christinaminty', 'avatar_url': 'https://avatars.githubusercontent.com/u/217627057?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1013885708, 'node_id': 'R_kgDOPG6rDA', 'name': 'data-engineering-zoomcamp', 'full_name': 'christinaminty/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'christinaminty', 'id': 217627057, 'node_id': 'U_kgDODPi5sQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/217627057?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/christinaminty', 'html_url': 'https://github.com/christinaminty', 'followers_url': 'https://api.github.com/users/christinaminty/followers', 'following_url': 'https://api.github.com/users/christinaminty/following{/other_user}', 'gists_url': 'https://api.github.com/users/christinaminty/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/christinaminty/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/christinaminty/subscriptions', 'organizations_url': 'https://api.github.com/users/christinaminty/orgs', 'repos_url': 'https://api.github.com/users/christinaminty/repos', 'events_url': 'https://api.github.com/users/christinaminty/events{/privacy}', 'received_events_url': 'https://api.github.com/users/christinaminty/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/christinaminty/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos ...
# Got page 9 with 30 records
# [{'id': '51662025446', 'type': 'WatchEvent', 'actor': {'id': 89319, 'login': 'ersatzryan', 'display_login': 'ersatzryan', 'gravatar_id': '', 'url': 'https://api.github.com/users/ersatzryan', 'avatar_url': 'https://avatars.githubusercontent.com/u/89319?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-03T14:44:27Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51660709536', 'type': 'ForkEvent', 'actor': {'id': 24599544, 'login': 'iAkashP', 'display_login': 'iAkashP', 'gravatar_id': '', 'url': 'https://api.github.com/users/iAkashP', 'avatar_url': 'https://avatars.githubusercontent.com/u/24599544?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1013206286, 'node_id': 'R_kgDOPGRNDg', 'name': 'data-engineering-zoomcamp', 'full_name': 'iAkashP/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'iAkashP', 'id': 24599544, 'node_id': 'MDQ6VXNlcjI0NTk5NTQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/24599544?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/iAkashP', 'html_url': 'https://github.com/iAkashP', 'followers_url': 'https://api.github.com/users/iAkashP/followers', 'following_url': 'https://api.github.com/users/iAkashP/following{/other_user}', 'gists_url': 'https://api.github.com/users/iAkashP/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/iAkashP/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/iAkashP/subscriptions', 'organizations_url': 'https://api.github.com/users/iAkashP/orgs', 'repos_url': 'https://api.github.com/users/iAkashP/repos', 'events_url': 'https://api.github.com/users/iAkashP/events{/privacy}', 'received_events_url': 'https://api.github.com/users/iAkashP/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/iAkashP/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/iAkashP/data- ...
# Got page 10 with 26 records
# [{'id': '51586324900', 'type': 'PullRequestEvent', 'actor': {'id': 206166622, 'login': 'chaiandmushrooms', 'display_login': 'chaiandmushrooms', 'gravatar_id': '', 'url': 'https://api.github.com/users/chaiandmushrooms', 'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'opened', 'number': 734, 'pull_request': {'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734', 'id': 2634176404, 'node_id': 'PR_kwDOGQOHdM6dAleU', 'html_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734', 'diff_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734.diff', 'patch_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734.patch', 'issue_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734', 'number': 734, 'state': 'open', 'locked': False, 'title': 'edited question and provided answers', 'user': {'login': 'chaiandmushrooms', 'id': 206166622, 'node_id': 'U_kgDODEnaXg', 'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/chaiandmushrooms', 'html_url': 'https://github.com/chaiandmushrooms', 'followers_url': 'https://api.github.com/users/chaiandmushrooms/followers', 'following_url': 'https://api.github.com/users/chaiandmushrooms/following{/other_user}', 'gists_url': 'https://api.github.com/users/chaiandmushrooms/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/chaiandmushrooms/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/chaiandmushrooms/subscriptions', 'organizations_url': 'https://api.github.com/users/chaiandmushrooms/orgs', 'repos_url': 'https://api.github.com/users/chaiandmushrooms/repos', 'events_url': 'https://api.github.com/users/chaiandmushrooms/events{/privacy}', 'received_events_url': 'https://api.github.com/users/chaiandmushrooms/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': 'edited one question (question no.5) and provided answers to all the question in week1 2024 cohort since no such resources were available. ', 'created_at': '2025-07-02T04:04:12Z', 'updated_at': '2025-07-02T04:04:12Z', 'closed_at': None, 'merged_at': None, 'merge_commit_sha': None, 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/commits', 'review_comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/comments', 'review_comment_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/comments{/number}', 'comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734/comments', 'statuses_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/statuses/6e3cb4be79b9de473d0e5ebaf2f7e8f2dedad90f', 'head': {'label': 'chaiandmushrooms:main', 'ref': 'main', 'sha': '6e3cb4be79b9de473d0e5ebaf2f7e8f2dedad90f', 'user': {'login': 'chaiandmushrooms', 'id': 206166622, 'node_id': 'U_kgDODEnaXg', 'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/chaiandmushrooms', 'html_url': 'https://github.com/chaiandmushrooms', 'followers_url': 'https://api.github.com/users/chaiandmushrooms/followers', 'following_url': 'https://api.github.com/users/chaiandmushrooms/following{/other_user}', 'gists_url': 'https://api.github.com/users/chaiandmushrooms/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/chaiandmushrooms/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/chaiandmushrooms/subscriptions', 'organizations_u ...

# %% [markdown]
# **What happens here:**
#
# - Starts at **page 1** and makes a **GET request** to the API.
# - Retrieves **JSON data**.
# - Looks for the **"next" page URL** in the response headers.
# - If a **next page exists**, updates `BASE_URL` and requests more data.
# - If there’s **no next page**, stops fetching and ends the loop.
#
# 💡 Different APIs handle pagination differently (some use offsets, cursors, page numbers, or tokens instead of links).

# %% [markdown]
# ---
#
# #### **4. Avoiding memory issues during extraction**
#
# To prevent your pipeline from crashing, we need to control memory usage.
#
# #### **Challenges with memory**
# - Many pipelines run on systems with limited memory, like serverless functions or shared clusters.
# - If you try to load all the data into memory at once, it can crash the entire system.
# - Even disk space can become an issue if you’re storing large amounts of data.

# %% [markdown]
# **The solution: batch processing / streaming data**
#
# **Streaming** means processing data in small chunks or events, rather than loading everything at once. This keeps memory usage low and ensures your pipeline remains efficient.
#
# As a data engineer, we will use streaming to transfer data between buffers, such as:
# - from APIs to local files;
# - from Webhooks to event queues;
# - from Event queues (like Kafka) to storage buckets.

# %%
from itertools import islice


# This function creates a generator that produces limit number of dictionaries.
def get_rows(limit):
    # Instead of storing all rows in memory, it yields one row at a time (lazy evaluation).
    yield from map(lambda n: {"row": n}, range(limit))


def data_chunked():
    rows = get_rows(10000)

    # Uses islice(rows, 1000) to take chunks of 1,000 rows at a time.
    while item_slice := list(islice(rows, 1000)):
        print(f"Got chunk of length {len(item_slice)}")
        # Each chunk is yielded as a list for further processing.
        yield item_slice


data = next(data_chunked())
# Out:
# Got chunk of length 1000

# %% [markdown]
# How it works:
# - Calls `get_rows(10000)`, generating 10,000 rows lazily.
# - Uses `islice(rows, 1000)` to take chunks of 1,000 rows at a time.
# - The `while` loop continues until all rows are processed.
# - Each chunk is yielded as a list for further processing.
# - Memory-efficient: Instead of keeping all 10,000 rows, it works with just 1,000 at a time.

# %%
import requests
from google.colab import userdata

API_TOKEN = userdata.get('ACCESS_TOKEN')
BASE_URL = "https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events"


def events_getter():
    page_number = 1
    url = BASE_URL

    while True:
        response = requests.get(url, headers={"Authorization": f"Bearer {API_TOKEN}"})
        page_data = response.json()
        yield page_data

        next_page = response.links.get("next", {}).get("url")

        if not next_page:
            break

        page_number += 1
        url = next_page


for events_page in events_getter():
    print(events_page)
# Out:
# [{'id': '52054879166', 'type': 'WatchEvent', 'actor': {'id': 212767187, 'login': 'reyaleman-tech', 'display_login': 'reyaleman-tech', 'gravatar_id': '', 'url': 'https://api.github.com/users/reyaleman-tech', 'avatar_url': 'https://avatars.githubusercontent.com/u/212767187?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-14T12:25:55Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52051650046', 'type': 'ForkEvent', 'actor': {'id': 91944358, 'login': 'qkrwnscjf', 'display_login': 'qkrwnscjf', 'gravatar_id': '', 'url': 'https://api.github.com/users/qkrwnscjf', 'avatar_url': 'https://avatars.githubusercontent.com/u/91944358?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1019462765, 'node_id': 'R_kgDOPMPEbQ', 'name': 'data-engineering-zoomcamp', 'full_name': 'qkrwnscjf/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'qkrwnscjf', 'id': 91944358, 'node_id': 'U_kgDOBXr1pg', 'avatar_url': 'https://avatars.githubusercontent.com/u/91944358?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/qkrwnscjf', 'html_url': 'https://github.com/qkrwnscjf', 'followers_url': 'https://api.github.com/users/qkrwnscjf/followers', 'following_url': 'https://api.github.com/users/qkrwnscjf/following{/other_user}', 'gists_url': 'https://api.github.com/users/qkrwnscjf/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/qkrwnscjf/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/qkrwnscjf/subscriptions', 'organizations_url': 'https://api.github.com/users/qkrwnscjf/orgs', 'repos_url': 'https://api.github.com/users/qkrwnscjf/repos', 'events_url': 'https://api.github.com/users/qkrwnscjf/events{/privacy}', 'received_events_url': 'https://api.github.com/users/qkrwnscjf/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/qkrwnscjf/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/qkrwnscjf/data-engineering-zoomcamp ...
# [{'id': '52014996769', 'type': 'WatchEvent', 'actor': {'id': 170357317, 'login': 'BrunoChiconato', 'display_login': 'BrunoChiconato', 'gravatar_id': '', 'url': 'https://api.github.com/users/BrunoChiconato', 'avatar_url': 'https://avatars.githubusercontent.com/u/170357317?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-13T01:17:15Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52014749536', 'type': 'WatchEvent', 'actor': {'id': 103594543, 'login': 'bautivizioli', 'display_login': 'bautivizioli', 'gravatar_id': '', 'url': 'https://api.github.com/users/bautivizioli', 'avatar_url': 'https://avatars.githubusercontent.com/u/103594543?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-13T00:52:15Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52013277236', 'type': 'WatchEvent', 'actor': {'id': 137610184, 'login': 'ryan-tilley', 'display_login': 'ryan-tilley', 'gravatar_id': '', 'url': 'https://api.github.com/users/ryan-tilley', 'avatar_url': 'https://avatars.githubusercontent.com/u/137610184?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-12T22:22:04Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52013032439', 'type': 'WatchEvent', 'actor': {'id': 15807184, 'login': 'NicolNonga', 'display_login': 'NicolNonga', 'gravatar_id': '', 'url': 'https://api.github.com/users/NicolNonga', 'avatar_url': 'https://avatars.githubusercontent.com/u/15807184?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-12T21:59:54Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '52012296833', 'type': 'ForkEvent', 'actor': {'id': 86207070, 'login': 'seunshix', 'display_login': 'seunshix', 'gravatar_id': '', 'url': 'https://api.github.com/users/seunshix', 'avatar_url': 'https://avatars.githubusercontent.com/u/86207070?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1018699766, 'node_id': 'R_kgDOPLgf9g', 'name': 'data-engineering-zoomcamp', 'full_name': 'seunshix/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'seunshix', 'id': 86207070, 'node_id': 'MDQ6VXNlcjg2MjA3MDcw', 'avatar_url': 'https://avatars.githubusercontent.com/u/86207070?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/seunshix', 'html_url': 'https://github.com/seunshix', 'followers_url': 'https://api.github.com/users/seunshix/followers', 'following_url': 'https://api.github.com/users/seunshix/following{/other_user}', 'gists_url': 'https://api.github.com/users/seunshix/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/seunshix/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.co ...
# [{'id': '51992777459', 'type': 'WatchEvent', 'actor': {'id': 121058317, 'login': '1-turbo', 'display_login': '1-turbo', 'gravatar_id': '', 'url': 'https://api.github.com/users/1-turbo', 'avatar_url': 'https://avatars.githubusercontent.com/u/121058317?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-11T20:48:28Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51990471054', 'type': 'WatchEvent', 'actor': {'id': 145046356, 'login': 'Nascfn', 'display_login': 'Nascfn', 'gravatar_id': '', 'url': 'https://api.github.com/users/Nascfn', 'avatar_url': 'https://avatars.githubusercontent.com/u/145046356?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-11T19:30:08Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51988449542', 'type': 'IssueCommentEvent', 'actor': {'id': 39490719, 'login': 'plpcout', 'display_login': 'plpcout', 'gravatar_id': '', 'url': 'https://api.github.com/users/plpcout', 'avatar_url': 'https://avatars.githubusercontent.com/u/39490719?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/727', 'repository_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp', 'labels_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/727/labels{/name}', 'comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/727/comments', 'events_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/727/events', 'html_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/727', 'id': 3037458306, 'node_id': 'PR_kwDOGQOHdM6U06W0', 'number': 727, 'title': 'docs: fix typos', 'user': {'login': 'plpcout', 'id': 39490719, 'node_id': 'MDQ6VXNlcjM5NDkwNzE5', 'avatar_url': 'https://avatars.githubusercontent.com/u/39490719?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/plpcout', 'html_url': 'https://github.com/plpcout', 'followers_url': 'https://api.github.com/users/plpcout/followers', 'following_url': 'https://api.github.com/users/plpcout/following{/other_user}', 'gists_url': 'https://api.github.com/users/plpcout/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/plpcout/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/plpcout/subscriptions', 'organizations_url': 'https://api.github.com/users/plpcout/orgs', 'repos_url': 'https://api.github.com/users/plpcout/repos', 'events_url': 'https://api.github.com/users/plpcout/events{/privacy}', 'received_events_url': 'https://api.github.com/users/plpcout/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'closed', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 2, 'created_at': '2025-05-03T15:09:52Z', 'updated_at': '2025-07-11T18:27:04Z', 'closed_at': '2025-07-10T08:17:42Z', 'author_association': 'CONTRIBUTOR', 'type': None, 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/727', 'html_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/727',  ...
# [{'id': '51896322464', 'type': 'WatchEvent', 'actor': {'id': 177606441, 'login': 'sykolax', 'display_login': 'sykolax', 'gravatar_id': '', 'url': 'https://api.github.com/users/sykolax', 'avatar_url': 'https://avatars.githubusercontent.com/u/177606441?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-09T20:19:13Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51895868895', 'type': 'WatchEvent', 'actor': {'id': 133255958, 'login': 'geeta-V', 'display_login': 'geeta-V', 'gravatar_id': '', 'url': 'https://api.github.com/users/geeta-V', 'avatar_url': 'https://avatars.githubusercontent.com/u/133255958?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-09T20:05:38Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51891923624', 'type': 'WatchEvent', 'actor': {'id': 182100393, 'login': 'httpmei', 'display_login': 'httpmei', 'gravatar_id': '', 'url': 'https://api.github.com/users/httpmei', 'avatar_url': 'https://avatars.githubusercontent.com/u/182100393?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-09T18:10:42Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51889549884', 'type': 'WatchEvent', 'actor': {'id': 58702367, 'login': 'Rajesh-B-Git', 'display_login': 'Rajesh-B-Git', 'gravatar_id': '', 'url': 'https://api.github.com/users/Rajesh-B-Git', 'avatar_url': 'https://avatars.githubusercontent.com/u/58702367?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-09T17:04:58Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51888295485', 'type': 'ForkEvent', 'actor': {'id': 26826719, 'login': 'arturcast', 'display_login': 'arturcast', 'gravatar_id': '', 'url': 'https://api.github.com/users/arturcast', 'avatar_url': 'https://avatars.githubusercontent.com/u/26826719?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1016861528, 'node_id': 'R_kgDOPJwTWA', 'name': 'data-engineering-zoomcamp', 'full_name': 'arturcast/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'arturcast', 'id': 26826719, 'node_id': 'MDQ6VXNlcjI2ODI2NzE5', 'avatar_url': 'https://avatars.githubusercontent.com/u/26826719?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/arturcast', 'html_url': 'https://github.com/arturcast', 'followers_url': 'https://api.github.com/users/arturcast/followers', 'following_url': 'https://api.github.com/users/arturcast/following{/other_user}', 'gists_url': 'https://api.github.com/users/arturcast/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/arturcast/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/arturcast/subscriptions ...
# [{'id': '51850066397', 'type': 'WatchEvent', 'actor': {'id': 63064972, 'login': 'Antoni00', 'display_login': 'Antoni00', 'gravatar_id': '', 'url': 'https://api.github.com/users/Antoni00', 'avatar_url': 'https://avatars.githubusercontent.com/u/63064972?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-08T22:16:04Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51849737429', 'type': 'WatchEvent', 'actor': {'id': 77596284, 'login': 'oscar2697', 'display_login': 'oscar2697', 'gravatar_id': '', 'url': 'https://api.github.com/users/oscar2697', 'avatar_url': 'https://avatars.githubusercontent.com/u/77596284?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-08T22:02:45Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51849367823', 'type': 'WatchEvent', 'actor': {'id': 103899744, 'login': 'mlopezgonzalez1105', 'display_login': 'mlopezgonzalez1105', 'gravatar_id': '', 'url': 'https://api.github.com/users/mlopezgonzalez1105', 'avatar_url': 'https://avatars.githubusercontent.com/u/103899744?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-08T21:48:59Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51849177963', 'type': 'WatchEvent', 'actor': {'id': 57726000, 'login': 'joaorty', 'display_login': 'joaorty', 'gravatar_id': '', 'url': 'https://api.github.com/users/joaorty', 'avatar_url': 'https://avatars.githubusercontent.com/u/57726000?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-08T21:41:54Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51848116845', 'type': 'ForkEvent', 'actor': {'id': 85909776, 'login': 'rcarreno90', 'display_login': 'rcarreno90', 'gravatar_id': '', 'url': 'https://api.github.com/users/rcarreno90', 'avatar_url': 'https://avatars.githubusercontent.com/u/85909776?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1016331361, 'node_id': 'R_kgDOPJP8YQ', 'name': 'data-engineering-zoomcamp', 'full_name': 'rcarreno90/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'rcarreno90', 'id': 85909776, 'node_id': 'MDQ6VXNlcjg1OTA5Nzc2', 'avatar_url': 'https://avatars.githubusercontent.com/u/85909776?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rcarreno90', 'html_url': 'https://github.com/rcarreno90', 'followers_url': 'https://api.github.com/users/rcarreno90/followers', 'following_url': 'https://api.github.com/users/rcarreno90/following{/other_user}', 'gists_url': 'https://api.github.com/users/rcarreno90/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rcarreno90/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github ...
# [{'id': '51799628188', 'type': 'WatchEvent', 'actor': {'id': 70458807, 'login': 'DataWithRyu', 'display_login': 'DataWithRyu', 'gravatar_id': '', 'url': 'https://api.github.com/users/DataWithRyu', 'avatar_url': 'https://avatars.githubusercontent.com/u/70458807?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-07T23:06:41Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51798452520', 'type': 'WatchEvent', 'actor': {'id': 129700252, 'login': 'MARSHALLSROR', 'display_login': 'MARSHALLSROR', 'gravatar_id': '', 'url': 'https://api.github.com/users/MARSHALLSROR', 'avatar_url': 'https://avatars.githubusercontent.com/u/129700252?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-07T22:16:48Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51794729519', 'type': 'WatchEvent', 'actor': {'id': 112006945, 'login': 'EmmaAcquah', 'display_login': 'EmmaAcquah', 'gravatar_id': '', 'url': 'https://api.github.com/users/EmmaAcquah', 'avatar_url': 'https://avatars.githubusercontent.com/u/112006945?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-07T20:13:38Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51789691412', 'type': 'ForkEvent', 'actor': {'id': 178495636, 'login': 's-gunde', 'display_login': 's-gunde', 'gravatar_id': '', 'url': 'https://api.github.com/users/s-gunde', 'avatar_url': 'https://avatars.githubusercontent.com/u/178495636?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1015573125, 'node_id': 'R_kgDOPIhqhQ', 'name': 'data-engineering-zoomcamp', 'full_name': 's-gunde/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 's-gunde', 'id': 178495636, 'node_id': 'U_kgDOCqOglA', 'avatar_url': 'https://avatars.githubusercontent.com/u/178495636?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/s-gunde', 'html_url': 'https://github.com/s-gunde', 'followers_url': 'https://api.github.com/users/s-gunde/followers', 'following_url': 'https://api.github.com/users/s-gunde/following{/other_user}', 'gists_url': 'https://api.github.com/users/s-gunde/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/s-gunde/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/s-gunde/subscriptions', 'organizations_url': 'https://api.github.com/users/s-gunde/orgs', 'repos_url': 'https://api.github.com/users/s-gunde/repos', 'events_url': 'https://api.github.com/users/s-gunde/events{/privacy}', 'received_events_url': 'https://api.github.com/users/s-gunde/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/s-gunde/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/s-gunde/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/s-gunde/data-engineering-zoomcamp ...
# [{'id': '51735738839', 'type': 'WatchEvent', 'actor': {'id': 96918614, 'login': 'June611', 'display_login': 'June611', 'gravatar_id': '', 'url': 'https://api.github.com/users/June611', 'avatar_url': 'https://avatars.githubusercontent.com/u/96918614?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-06T03:04:20Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51733696242', 'type': 'WatchEvent', 'actor': {'id': 77160481, 'login': 'davramuk', 'display_login': 'davramuk', 'gravatar_id': '', 'url': 'https://api.github.com/users/davramuk', 'avatar_url': 'https://avatars.githubusercontent.com/u/77160481?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-05T23:33:21Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51732841906', 'type': 'WatchEvent', 'actor': {'id': 73328672, 'login': 'matthewwithers', 'display_login': 'matthewwithers', 'gravatar_id': '', 'url': 'https://api.github.com/users/matthewwithers', 'avatar_url': 'https://avatars.githubusercontent.com/u/73328672?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-05T22:06:53Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51732544862', 'type': 'WatchEvent', 'actor': {'id': 71408433, 'login': 'nudwix', 'display_login': 'nudwix', 'gravatar_id': '', 'url': 'https://api.github.com/users/nudwix', 'avatar_url': 'https://avatars.githubusercontent.com/u/71408433?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-05T21:38:27Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51732084728', 'type': 'WatchEvent', 'actor': {'id': 41239149, 'login': 'ymtqyl', 'display_login': 'ymtqyl', 'gravatar_id': '', 'url': 'https://api.github.com/users/ymtqyl', 'avatar_url': 'https://avatars.githubusercontent.com/u/41239149?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-05T20:57:02Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51731218226', 'type': 'WatchEvent', 'actor': {'id': 100478220, 'login': 'yashmittalz', 'display_login': 'yashmittalz', 'gravatar_id': '', 'url': 'https://api.github.com/users/yashmittalz', 'avatar_url': 'https://avatars.githubusercontent.com/u/100478220?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-05T19:40:37Z', 'org': {'id': 72699292, 'login': 'D ...
# [{'id': '51709392734', 'type': 'WatchEvent', 'actor': {'id': 88166669, 'login': 'benboam', 'display_login': 'benboam', 'gravatar_id': '', 'url': 'https://api.github.com/users/benboam', 'avatar_url': 'https://avatars.githubusercontent.com/u/88166669?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-04T16:40:25Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51708939260', 'type': 'ForkEvent', 'actor': {'id': 217627057, 'login': 'christinaminty', 'display_login': 'christinaminty', 'gravatar_id': '', 'url': 'https://api.github.com/users/christinaminty', 'avatar_url': 'https://avatars.githubusercontent.com/u/217627057?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1013885708, 'node_id': 'R_kgDOPG6rDA', 'name': 'data-engineering-zoomcamp', 'full_name': 'christinaminty/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'christinaminty', 'id': 217627057, 'node_id': 'U_kgDODPi5sQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/217627057?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/christinaminty', 'html_url': 'https://github.com/christinaminty', 'followers_url': 'https://api.github.com/users/christinaminty/followers', 'following_url': 'https://api.github.com/users/christinaminty/following{/other_user}', 'gists_url': 'https://api.github.com/users/christinaminty/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/christinaminty/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/christinaminty/subscriptions', 'organizations_url': 'https://api.github.com/users/christinaminty/orgs', 'repos_url': 'https://api.github.com/users/christinaminty/repos', 'events_url': 'https://api.github.com/users/christinaminty/events{/privacy}', 'received_events_url': 'https://api.github.com/users/christinaminty/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/christinaminty/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/christinaminty/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos ...
# [{'id': '51662025446', 'type': 'WatchEvent', 'actor': {'id': 89319, 'login': 'ersatzryan', 'display_login': 'ersatzryan', 'gravatar_id': '', 'url': 'https://api.github.com/users/ersatzryan', 'avatar_url': 'https://avatars.githubusercontent.com/u/89319?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-07-03T14:44:27Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '51660709536', 'type': 'ForkEvent', 'actor': {'id': 24599544, 'login': 'iAkashP', 'display_login': 'iAkashP', 'gravatar_id': '', 'url': 'https://api.github.com/users/iAkashP', 'avatar_url': 'https://avatars.githubusercontent.com/u/24599544?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 1013206286, 'node_id': 'R_kgDOPGRNDg', 'name': 'data-engineering-zoomcamp', 'full_name': 'iAkashP/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'iAkashP', 'id': 24599544, 'node_id': 'MDQ6VXNlcjI0NTk5NTQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/24599544?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/iAkashP', 'html_url': 'https://github.com/iAkashP', 'followers_url': 'https://api.github.com/users/iAkashP/followers', 'following_url': 'https://api.github.com/users/iAkashP/following{/other_user}', 'gists_url': 'https://api.github.com/users/iAkashP/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/iAkashP/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/iAkashP/subscriptions', 'organizations_url': 'https://api.github.com/users/iAkashP/orgs', 'repos_url': 'https://api.github.com/users/iAkashP/repos', 'events_url': 'https://api.github.com/users/iAkashP/events{/privacy}', 'received_events_url': 'https://api.github.com/users/iAkashP/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/iAkashP/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/iAkashP/data-engineering-zoomcamp/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/iAkashP/data- ...
# [{'id': '51586324900', 'type': 'PullRequestEvent', 'actor': {'id': 206166622, 'login': 'chaiandmushrooms', 'display_login': 'chaiandmushrooms', 'gravatar_id': '', 'url': 'https://api.github.com/users/chaiandmushrooms', 'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'opened', 'number': 734, 'pull_request': {'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734', 'id': 2634176404, 'node_id': 'PR_kwDOGQOHdM6dAleU', 'html_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734', 'diff_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734.diff', 'patch_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734.patch', 'issue_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734', 'number': 734, 'state': 'open', 'locked': False, 'title': 'edited question and provided answers', 'user': {'login': 'chaiandmushrooms', 'id': 206166622, 'node_id': 'U_kgDODEnaXg', 'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/chaiandmushrooms', 'html_url': 'https://github.com/chaiandmushrooms', 'followers_url': 'https://api.github.com/users/chaiandmushrooms/followers', 'following_url': 'https://api.github.com/users/chaiandmushrooms/following{/other_user}', 'gists_url': 'https://api.github.com/users/chaiandmushrooms/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/chaiandmushrooms/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/chaiandmushrooms/subscriptions', 'organizations_url': 'https://api.github.com/users/chaiandmushrooms/orgs', 'repos_url': 'https://api.github.com/users/chaiandmushrooms/repos', 'events_url': 'https://api.github.com/users/chaiandmushrooms/events{/privacy}', 'received_events_url': 'https://api.github.com/users/chaiandmushrooms/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': 'edited one question (question no.5) and provided answers to all the question in week1 2024 cohort since no such resources were available. ', 'created_at': '2025-07-02T04:04:12Z', 'updated_at': '2025-07-02T04:04:12Z', 'closed_at': None, 'merged_at': None, 'merge_commit_sha': None, 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/commits', 'review_comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/comments', 'review_comment_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/comments{/number}', 'comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734/comments', 'statuses_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/statuses/6e3cb4be79b9de473d0e5ebaf2f7e8f2dedad90f', 'head': {'label': 'chaiandmushrooms:main', 'ref': 'main', 'sha': '6e3cb4be79b9de473d0e5ebaf2f7e8f2dedad90f', 'user': {'login': 'chaiandmushrooms', 'id': 206166622, 'node_id': 'U_kgDODEnaXg', 'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/chaiandmushrooms', 'html_url': 'https://github.com/chaiandmushrooms', 'followers_url': 'https://api.github.com/users/chaiandmushrooms/followers', 'following_url': 'https://api.github.com/users/chaiandmushrooms/following{/other_user}', 'gists_url': 'https://api.github.com/users/chaiandmushrooms/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/chaiandmushrooms/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/chaiandmushrooms/subscriptions', 'organizations_u ...

# %% [markdown]
# In this approach to grabbing data from APIs, there are both pros and cons:
#
# ✅ Pros: **Easy memory management** since the API returns data in small pages or events.
# ❌ Cons: **Low throughput** because data transfer is limited by API constraints (rate limits, response time).

# %% [markdown]
# ## **Normalizing data**
#
# Data cleaning typically involves two key steps:
#
# 1. **Normalizing data** – Structuring and standardizing data **without changing its meaning**.
# 2. **Filtering data for a specific use case** – Selecting or modifying data **in a way that changes its meaning** to fit the analysis.

# %% [markdown]
# ---
#
# ### **Why prepare data? Why not use JSON directly?**
#
# While JSON is a great format for **data transfer**, it’s not ideal for analysis. Here’s why:
#
# ❌ **No enforced schema** – We don’t always know what fields exist in a JSON document.
# ❌ **Inconsistent data types** – A field like `age` might appear as `25`, `"twenty five"`, or `25.00`, which can break downstream applications.
# ❌ **Hard to process** – If we need to group data by day, we must manually convert date strings to timestamps.
# ❌ **Memory-heavy** – JSON requires reading the entire file into memory, unlike databases or columnar formats that allow scanning just the necessary fields.
# ❌ **Slow for aggregation and search** – JSON is not optimized for quick lookups or aggregations like columnar formats (e.g., Parquet).
#
#
# JSON is great for **data exchange** but **not for direct analytical use**. To make data useful, we need to **normalize it** — flattening, typing, and structuring it for efficiency.

# %%
event = events_page[0]
event
# Out:
# {'id': '51586324900',
#  'type': 'PullRequestEvent',
#  'actor': {'id': 206166622,
#   'login': 'chaiandmushrooms',
#   'display_login': 'chaiandmushrooms',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/chaiandmushrooms',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?'},
#  'repo': {'id': 419661684,
#   'name': 'DataTalksClub/data-engineering-zoomcamp',
#   'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#  'payload': {'action': 'opened',
#   'number': 734,
#   'pull_request': {'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734',
#    'id': 2634176404,
#    'node_id': 'PR_kwDOGQOHdM6dAleU',
#    'html_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734',
#    'diff_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734.diff',
#    'patch_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734.patch',
#    'issue_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734',
#    'number': 734,
#    'state': 'open',
#    'locked': False,
#    'title': 'edited question and provided answers',
#    'user': {'login': 'chaiandmushrooms',
#     'id': 206166622,
#     'node_id': 'U_kgDODEnaXg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/chaiandmushrooms',
#     'html_url': 'https://github.com/chaiandmushrooms',
#     'followers_url': 'https://api.github.com/users/chaiandmushrooms/followers',
#     'following_url': 'https://api.github.com/users/chaiandmushrooms/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/chaiandmushrooms/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/chaiandmushrooms/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/chaiandmushrooms/subscriptions',
#     'organizations_url': 'https://api.github.com/users/chaiandmushrooms/orgs',
#     'repos_url': 'https://api.github.com/users/chaiandmushrooms/repos',
#     'events_url': 'https://api.github.com/users/chaiandmushrooms/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/chaiandmushrooms/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'body': 'edited one question (question no.5) and provided answers to all the question in week1 2024 cohort since no such resources were available. ',
#    'created_at': '2025-07-02T04:04:12Z',
#    'updated_at': '2025-07-02T04:04:12Z',
#    'closed_at': None,
#    'merged_at': None,
#    'merge_commit_sha': None,
#    'assignee': None,
#    'assignees': [],
#    'requested_reviewers': [],
#    'requested_teams': [],
#    'labels': [],
#    'milestone': None,
#    'draft': False,
#    'commits_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/commits',
#    'review_comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/comments',
#    'review_comment_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/comments{/number}',
#    'comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734/comments',
#    'statuses_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/statuses/6e3cb4be79b9de473d0e5ebaf2f7e8f2dedad90f',
#    'head': {'label': 'chaiandmushrooms:main',
#     'ref': 'main',
#     'sha': '6e3cb4be79b9de473d0e5ebaf2f7e8f2dedad90f',
#     'user': {'login': 'chaiandmushrooms',
#      'id': 206166622,
#      'node_id': 'U_kgDODEnaXg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/chaiandmushrooms',
#      'html_url': 'https://github.com/chaiandmushrooms',
#      'followers_url': 'https://api.github.com/users/chaiandmushrooms/followers',
#      'following_url': 'https://api.github.com/users/chaiandmushrooms/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/chaiandmushrooms/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/chaiandmushrooms/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/chaiandmushrooms/subscriptions',
#      'organizations_url': 'https://api.github.com/users/chaiandmushrooms/orgs',
#      'repos_url': 'https://api.github.com/users/chaiandmushrooms/repos',
#      'events_url': 'https://api.github.com/users/chaiandmushrooms/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/chaiandmushrooms/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'repo': {'id': 1011930492,
#      'node_id': 'R_kgDOPFDVfA',
#      'name': 'data-engineering-zoomcamp',
#      'full_name': 'chaiandmushrooms/data-engineering-zoomcamp',
#      'private': False,
#      'owner': {'login': 'chaiandmushrooms',
#       'id': 206166622,
#       'node_id': 'U_kgDODEnaXg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/chaiandmushrooms',
#       'html_url': 'https://github.com/chaiandmushrooms',
#       'followers_url': 'https://api.github.com/users/chaiandmushrooms/followers',
#       'following_url': 'https://api.github.com/users/chaiandmushrooms/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/chaiandmushrooms/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/chaiandmushrooms/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/chaiandmushrooms/subscriptions',
#       'organizations_url': 'https://api.github.com/users/chaiandmushrooms/orgs',
#       'repos_url': 'https://api.github.com/users/chaiandmushrooms/repos',
#       'events_url': 'https://api.github.com/users/chaiandmushrooms/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/chaiandmushrooms/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'html_url': 'https://github.com/chaiandmushrooms/data-engineering-zoomcamp',
#      'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#      'fork': True,
#      'url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp',
#      'forks_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/forks',
#      'keys_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/keys{/key_id}',
#      'collaborators_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/collaborators{/collaborator}',
#      'teams_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/teams',
#      'hooks_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/hooks',
#      'issue_events_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/issues/events{/number}',
#      'events_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/events',
#      'assignees_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/assignees{/user}',
#      'branches_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/branches{/branch}',
#      'tags_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/tags',
#      'blobs_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/git/blobs{/sha}',
#      'git_tags_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/git/tags{/sha}',
#      'git_refs_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/git/refs{/sha}',
#      'trees_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/git/trees{/sha}',
#      'statuses_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/statuses/{sha}',
#      'languages_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/languages',
#      'stargazers_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/stargazers',
#      'contributors_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/contributors',
#      'subscribers_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/subscribers',
#      'subscription_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/subscription',
#      'commits_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/commits{/sha}',
#      'git_commits_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/git/commits{/sha}',
#      'comments_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/comments{/number}',
#      'issue_comment_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/issues/comments{/number}',
#      'contents_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/contents/{+path}',
#      'compare_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/compare/{base}...{head}',
#      'merges_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/merges',
#      'archive_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/{archive_format}{/ref}',
#      'downloads_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/downloads',
#      'issues_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/issues{/number}',
#      'pulls_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/pulls{/number}',
#      'milestones_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/milestones{/number}',
#      'notifications_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/notifications{?since,all,participating}',
#      'labels_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/labels{/name}',
#      'releases_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/releases{/id}',
#      'deployments_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/deployments',
#      'created_at': '2025-07-01T14:47:07Z',
#      'updated_at': '2025-07-02T04:02:29Z',
#      'pushed_at': '2025-07-02T04:02:26Z',
#      'git_url': 'git://github.com/chaiandmushrooms/data-engineering-zoomcamp.git',
#      'ssh_url': 'git@github.com:chaiandmushrooms/data-engineering-zoomcamp.git',
#      'clone_url': 'https://github.com/chaiandmushrooms/data-engineering-zoomcamp.git',
#      'svn_url': 'https://github.com/chaiandmushrooms/data-engineering-zoomcamp',
#      'homepage': '',
#      'size': 8743,
#      'stargazers_count': 0,
#      'watchers_count': 0,
#      'language': 'Jupyter Notebook',
#      'has_issues': False,
#      'has_projects': True,
#      'has_downloads': True,
#      'has_wiki': True,
#      'has_pages': False,
#      'has_discussions': False,
#      'forks_count': 0,
#      'mirror_url': None,
#      'archived': False,
#      'disabled': False,
#      'open_issues_count': 0,
#      'license': None,
#      'allow_forking': True,
#      'is_template': False,
#      'web_commit_signoff_required': False,
#      'topics': [],
#      'visibility': 'public',
#      'forks': 0,
#      'open_issues': 0,
#      'watchers': 0,
#      'default_branch': 'main'}},
#    'base': {'label': 'DataTalksClub:main',
#     'ref': 'main',
#     'sha': '1218cfa636d28b5f8d98e71514f78f45310c01ff',
#     'user': {'login': 'DataTalksClub',
#      'id': 72699292,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjcyNjk5Mjky',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/DataTalksClub',
#      'html_url': 'https://github.com/DataTalksClub',
#      'followers_url': 'https://api.github.com/users/DataTalksClub/followers',
#      'following_url': 'https://api.github.com/users/DataTalksClub/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DataTalksClub/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/DataTalksClub/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DataTalksClub/subscriptions',
#      'organizations_url': 'https://api.github.com/users/DataTalksClub/orgs',
#      'repos_url': 'https://api.github.com/users/DataTalksClub/repos',
#      'events_url': 'https://api.github.com/users/DataTalksClub/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/DataTalksClub/received_events',
#      'type': 'Organization',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'repo': {'id': 419661684,
#      'node_id': 'R_kgDOGQOHdA',
#      'name': 'data-engineering-zoomcamp',
#      'full_name': 'DataTalksClub/data-engineering-zoomcamp',
#      'private': False,
#      'owner': {'login': 'DataTalksClub',
#       'id': 72699292,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjcyNjk5Mjky',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/DataTalksClub',
#       'html_url': 'https://github.com/DataTalksClub',
#       'followers_url': 'https://api.github.com/users/DataTalksClub/followers',
#       'following_url': 'https://api.github.com/users/DataTalksClub/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/DataTalksClub/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/DataTalksClub/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/DataTalksClub/subscriptions',
#       'organizations_url': 'https://api.github.com/users/DataTalksClub/orgs',
#       'repos_url': 'https://api.github.com/users/DataTalksClub/repos',
#       'events_url': 'https://api.github.com/users/DataTalksClub/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/DataTalksClub/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'html_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp',
#      'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#      'fork': False,
#      'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp',
#      'forks_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/forks',
#      'keys_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/keys{/key_id}',
#      'collaborators_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/collaborators{/collaborator}',
#      'teams_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/teams',
#      'hooks_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/hooks',
#      'issue_events_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/events{/number}',
#      'events_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events',
#      'assignees_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/assignees{/user}',
#      'branches_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/branches{/branch}',
#      'tags_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/tags',
#      'blobs_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/git/blobs{/sha}',
#      'git_tags_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/git/tags{/sha}',
#      'git_refs_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/git/refs{/sha}',
#      'trees_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/git/trees{/sha}',
#      'statuses_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/statuses/{sha}',
#      'languages_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/languages',
#      'stargazers_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/stargazers',
#      'contributors_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/contributors',
#      'subscribers_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/subscribers',
#      'subscription_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/subscription',
#      'commits_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/commits{/sha}',
#      'git_commits_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/git/commits{/sha}',
#      'comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/comments{/number}',
#      'issue_comment_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/comments{/number}',
#      'contents_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/contents/{+path}',
#      'compare_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/compare/{base}...{head}',
#      'merges_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/merges',
#      'archive_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/{archive_format}{/ref}',
#      'downloads_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/downloads',
#      'issues_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues{/number}',
#      'pulls_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls{/number}',
#      'milestones_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/milestones{/number}',
#      'notifications_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/notifications{?since,all,participating}',
#      'labels_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/labels{/name}',
#      'releases_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/releases{/id}',
#      'deployments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/deployments',
#      'created_at': '2021-10-21T09:32:50Z',
#      'updated_at': '2025-07-02T03:51:54Z',
#      'pushed_at': '2025-06-27T14:21:06Z',
#      'git_url': 'git://github.com/DataTalksClub/data-engineering-zoomcamp.git',
#      'ssh_url': 'git@github.com:DataTalksClub/data-engineering-zoomcamp.git',
#      'clone_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp.git',
#      'svn_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp',
#      'homepage': '',
#      'size': 8743,
#      'stargazers_count': 31617,
#      'watchers_count': 31617,
#      'language': 'Jupyter Notebook',
#      'has_issues': True,
#      'has_projects': True,
#      'has_downloads': True,
#      'has_wiki': True,
#      'has_pages': False,
#      'has_discussions': False,
#      'forks_count': 6714,
#      'mirror_url': None,
#      'archived': False,
#      'disabled': False,
#      'open_issues_count': 6,
#      'license': None,
#      'allow_forking': True,
#      'is_template': False,
#      'web_commit_signoff_required': False,
#      'topics': ['data-engineering',
#       'dbt',
#       'docker',
#       'kafka',
#       'kestra',
#       'spark'],
#      'visibility': 'public',
#      'forks': 6714,
#      'open_issues': 6,
#      'watchers': 31617,
#      'default_branch': 'main'}},
#    '_links': {'self': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734'},
#     'html': {'href': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734'},
#     'issue': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734'},
#     'comments': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734/comments'},
#     'review_comments': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/comments'},
#     'review_comment': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/comments{/number}'},
#     'commits': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/commits'},
#     'statuses': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/statuses/6e3cb4be79b9de473d0e5ebaf2f7e8f2dedad90f'}},
#    'author_association': 'NONE',
#    'auto_merge': None,
#    'active_lock_reason': None,
#    'merged': False,
#    'mergeable': None,
#    'rebaseable': None,
#    'mergeable_state': 'unknown',
#    'merged_by': None,
#    'comments': 0,
#    'review_comments': 0,
#    'maintainer_can_modify': True,
#    'commits': 2,
#    'additions': 143,
#    'deletions': 1,
#    'changed_files': 2}},
#  'public': True,
#  'created_at': '2025-07-02T04:04:13Z',
#  'org': {'id': 72699292,
#   'login': 'DataTalksClub',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/orgs/DataTalksClub',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}

# %%
event.keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at', 'org'])

# %% [markdown]
# The data we retrieved from the API has **a nested JSON format**. Let's unnest it!
#
# > It means that any **nested structures** (like dictionaries and lists) have to be flattened, to make it easier to store and query in a database or a dataframe.
#
#
# ---
#
# ### **How to processed this data?**
#
# 1️⃣ **Flatten nested fields:**
#    - For example, fields `actor`, `repo`, `payload` and `org` are nested and we should extract all the necessary data:
#      ```json
#      'actor': {
#         'id': 198386041,
#         'login': 'Anqi0607',
#         ...
#      ```
#      to:
#      ```json
#      'actor__id': 198386041,
#      'actor__login': 'Anqi0607',
#      ...
#      ```

# %%
event
# Out:
# {'id': '51586324900',
#  'type': 'PullRequestEvent',
#  'actor': {'id': 206166622,
#   'login': 'chaiandmushrooms',
#   'display_login': 'chaiandmushrooms',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/chaiandmushrooms',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?'},
#  'repo': {'id': 419661684,
#   'name': 'DataTalksClub/data-engineering-zoomcamp',
#   'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#  'payload': {'action': 'opened',
#   'number': 734,
#   'pull_request': {'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734',
#    'id': 2634176404,
#    'node_id': 'PR_kwDOGQOHdM6dAleU',
#    'html_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734',
#    'diff_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734.diff',
#    'patch_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734.patch',
#    'issue_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734',
#    'number': 734,
#    'state': 'open',
#    'locked': False,
#    'title': 'edited question and provided answers',
#    'user': {'login': 'chaiandmushrooms',
#     'id': 206166622,
#     'node_id': 'U_kgDODEnaXg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/chaiandmushrooms',
#     'html_url': 'https://github.com/chaiandmushrooms',
#     'followers_url': 'https://api.github.com/users/chaiandmushrooms/followers',
#     'following_url': 'https://api.github.com/users/chaiandmushrooms/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/chaiandmushrooms/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/chaiandmushrooms/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/chaiandmushrooms/subscriptions',
#     'organizations_url': 'https://api.github.com/users/chaiandmushrooms/orgs',
#     'repos_url': 'https://api.github.com/users/chaiandmushrooms/repos',
#     'events_url': 'https://api.github.com/users/chaiandmushrooms/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/chaiandmushrooms/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'body': 'edited one question (question no.5) and provided answers to all the question in week1 2024 cohort since no such resources were available. ',
#    'created_at': '2025-07-02T04:04:12Z',
#    'updated_at': '2025-07-02T04:04:12Z',
#    'closed_at': None,
#    'merged_at': None,
#    'merge_commit_sha': None,
#    'assignee': None,
#    'assignees': [],
#    'requested_reviewers': [],
#    'requested_teams': [],
#    'labels': [],
#    'milestone': None,
#    'draft': False,
#    'commits_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/commits',
#    'review_comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/comments',
#    'review_comment_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/comments{/number}',
#    'comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734/comments',
#    'statuses_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/statuses/6e3cb4be79b9de473d0e5ebaf2f7e8f2dedad90f',
#    'head': {'label': 'chaiandmushrooms:main',
#     'ref': 'main',
#     'sha': '6e3cb4be79b9de473d0e5ebaf2f7e8f2dedad90f',
#     'user': {'login': 'chaiandmushrooms',
#      'id': 206166622,
#      'node_id': 'U_kgDODEnaXg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/chaiandmushrooms',
#      'html_url': 'https://github.com/chaiandmushrooms',
#      'followers_url': 'https://api.github.com/users/chaiandmushrooms/followers',
#      'following_url': 'https://api.github.com/users/chaiandmushrooms/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/chaiandmushrooms/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/chaiandmushrooms/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/chaiandmushrooms/subscriptions',
#      'organizations_url': 'https://api.github.com/users/chaiandmushrooms/orgs',
#      'repos_url': 'https://api.github.com/users/chaiandmushrooms/repos',
#      'events_url': 'https://api.github.com/users/chaiandmushrooms/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/chaiandmushrooms/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'repo': {'id': 1011930492,
#      'node_id': 'R_kgDOPFDVfA',
#      'name': 'data-engineering-zoomcamp',
#      'full_name': 'chaiandmushrooms/data-engineering-zoomcamp',
#      'private': False,
#      'owner': {'login': 'chaiandmushrooms',
#       'id': 206166622,
#       'node_id': 'U_kgDODEnaXg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/206166622?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/chaiandmushrooms',
#       'html_url': 'https://github.com/chaiandmushrooms',
#       'followers_url': 'https://api.github.com/users/chaiandmushrooms/followers',
#       'following_url': 'https://api.github.com/users/chaiandmushrooms/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/chaiandmushrooms/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/chaiandmushrooms/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/chaiandmushrooms/subscriptions',
#       'organizations_url': 'https://api.github.com/users/chaiandmushrooms/orgs',
#       'repos_url': 'https://api.github.com/users/chaiandmushrooms/repos',
#       'events_url': 'https://api.github.com/users/chaiandmushrooms/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/chaiandmushrooms/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'html_url': 'https://github.com/chaiandmushrooms/data-engineering-zoomcamp',
#      'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#      'fork': True,
#      'url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp',
#      'forks_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/forks',
#      'keys_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/keys{/key_id}',
#      'collaborators_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/collaborators{/collaborator}',
#      'teams_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/teams',
#      'hooks_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/hooks',
#      'issue_events_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/issues/events{/number}',
#      'events_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/events',
#      'assignees_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/assignees{/user}',
#      'branches_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/branches{/branch}',
#      'tags_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/tags',
#      'blobs_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/git/blobs{/sha}',
#      'git_tags_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/git/tags{/sha}',
#      'git_refs_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/git/refs{/sha}',
#      'trees_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/git/trees{/sha}',
#      'statuses_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/statuses/{sha}',
#      'languages_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/languages',
#      'stargazers_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/stargazers',
#      'contributors_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/contributors',
#      'subscribers_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/subscribers',
#      'subscription_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/subscription',
#      'commits_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/commits{/sha}',
#      'git_commits_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/git/commits{/sha}',
#      'comments_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/comments{/number}',
#      'issue_comment_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/issues/comments{/number}',
#      'contents_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/contents/{+path}',
#      'compare_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/compare/{base}...{head}',
#      'merges_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/merges',
#      'archive_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/{archive_format}{/ref}',
#      'downloads_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/downloads',
#      'issues_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/issues{/number}',
#      'pulls_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/pulls{/number}',
#      'milestones_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/milestones{/number}',
#      'notifications_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/notifications{?since,all,participating}',
#      'labels_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/labels{/name}',
#      'releases_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/releases{/id}',
#      'deployments_url': 'https://api.github.com/repos/chaiandmushrooms/data-engineering-zoomcamp/deployments',
#      'created_at': '2025-07-01T14:47:07Z',
#      'updated_at': '2025-07-02T04:02:29Z',
#      'pushed_at': '2025-07-02T04:02:26Z',
#      'git_url': 'git://github.com/chaiandmushrooms/data-engineering-zoomcamp.git',
#      'ssh_url': 'git@github.com:chaiandmushrooms/data-engineering-zoomcamp.git',
#      'clone_url': 'https://github.com/chaiandmushrooms/data-engineering-zoomcamp.git',
#      'svn_url': 'https://github.com/chaiandmushrooms/data-engineering-zoomcamp',
#      'homepage': '',
#      'size': 8743,
#      'stargazers_count': 0,
#      'watchers_count': 0,
#      'language': 'Jupyter Notebook',
#      'has_issues': False,
#      'has_projects': True,
#      'has_downloads': True,
#      'has_wiki': True,
#      'has_pages': False,
#      'has_discussions': False,
#      'forks_count': 0,
#      'mirror_url': None,
#      'archived': False,
#      'disabled': False,
#      'open_issues_count': 0,
#      'license': None,
#      'allow_forking': True,
#      'is_template': False,
#      'web_commit_signoff_required': False,
#      'topics': [],
#      'visibility': 'public',
#      'forks': 0,
#      'open_issues': 0,
#      'watchers': 0,
#      'default_branch': 'main'}},
#    'base': {'label': 'DataTalksClub:main',
#     'ref': 'main',
#     'sha': '1218cfa636d28b5f8d98e71514f78f45310c01ff',
#     'user': {'login': 'DataTalksClub',
#      'id': 72699292,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjcyNjk5Mjky',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/DataTalksClub',
#      'html_url': 'https://github.com/DataTalksClub',
#      'followers_url': 'https://api.github.com/users/DataTalksClub/followers',
#      'following_url': 'https://api.github.com/users/DataTalksClub/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DataTalksClub/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/DataTalksClub/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DataTalksClub/subscriptions',
#      'organizations_url': 'https://api.github.com/users/DataTalksClub/orgs',
#      'repos_url': 'https://api.github.com/users/DataTalksClub/repos',
#      'events_url': 'https://api.github.com/users/DataTalksClub/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/DataTalksClub/received_events',
#      'type': 'Organization',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'repo': {'id': 419661684,
#      'node_id': 'R_kgDOGQOHdA',
#      'name': 'data-engineering-zoomcamp',
#      'full_name': 'DataTalksClub/data-engineering-zoomcamp',
#      'private': False,
#      'owner': {'login': 'DataTalksClub',
#       'id': 72699292,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjcyNjk5Mjky',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/DataTalksClub',
#       'html_url': 'https://github.com/DataTalksClub',
#       'followers_url': 'https://api.github.com/users/DataTalksClub/followers',
#       'following_url': 'https://api.github.com/users/DataTalksClub/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/DataTalksClub/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/DataTalksClub/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/DataTalksClub/subscriptions',
#       'organizations_url': 'https://api.github.com/users/DataTalksClub/orgs',
#       'repos_url': 'https://api.github.com/users/DataTalksClub/repos',
#       'events_url': 'https://api.github.com/users/DataTalksClub/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/DataTalksClub/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'html_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp',
#      'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#      'fork': False,
#      'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp',
#      'forks_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/forks',
#      'keys_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/keys{/key_id}',
#      'collaborators_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/collaborators{/collaborator}',
#      'teams_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/teams',
#      'hooks_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/hooks',
#      'issue_events_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/events{/number}',
#      'events_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events',
#      'assignees_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/assignees{/user}',
#      'branches_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/branches{/branch}',
#      'tags_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/tags',
#      'blobs_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/git/blobs{/sha}',
#      'git_tags_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/git/tags{/sha}',
#      'git_refs_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/git/refs{/sha}',
#      'trees_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/git/trees{/sha}',
#      'statuses_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/statuses/{sha}',
#      'languages_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/languages',
#      'stargazers_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/stargazers',
#      'contributors_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/contributors',
#      'subscribers_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/subscribers',
#      'subscription_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/subscription',
#      'commits_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/commits{/sha}',
#      'git_commits_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/git/commits{/sha}',
#      'comments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/comments{/number}',
#      'issue_comment_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/comments{/number}',
#      'contents_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/contents/{+path}',
#      'compare_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/compare/{base}...{head}',
#      'merges_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/merges',
#      'archive_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/{archive_format}{/ref}',
#      'downloads_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/downloads',
#      'issues_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues{/number}',
#      'pulls_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls{/number}',
#      'milestones_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/milestones{/number}',
#      'notifications_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/notifications{?since,all,participating}',
#      'labels_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/labels{/name}',
#      'releases_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/releases{/id}',
#      'deployments_url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/deployments',
#      'created_at': '2021-10-21T09:32:50Z',
#      'updated_at': '2025-07-02T03:51:54Z',
#      'pushed_at': '2025-06-27T14:21:06Z',
#      'git_url': 'git://github.com/DataTalksClub/data-engineering-zoomcamp.git',
#      'ssh_url': 'git@github.com:DataTalksClub/data-engineering-zoomcamp.git',
#      'clone_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp.git',
#      'svn_url': 'https://github.com/DataTalksClub/data-engineering-zoomcamp',
#      'homepage': '',
#      'size': 8743,
#      'stargazers_count': 31617,
#      'watchers_count': 31617,
#      'language': 'Jupyter Notebook',
#      'has_issues': True,
#      'has_projects': True,
#      'has_downloads': True,
#      'has_wiki': True,
#      'has_pages': False,
#      'has_discussions': False,
#      'forks_count': 6714,
#      'mirror_url': None,
#      'archived': False,
#      'disabled': False,
#      'open_issues_count': 6,
#      'license': None,
#      'allow_forking': True,
#      'is_template': False,
#      'web_commit_signoff_required': False,
#      'topics': ['data-engineering',
#       'dbt',
#       'docker',
#       'kafka',
#       'kestra',
#       'spark'],
#      'visibility': 'public',
#      'forks': 6714,
#      'open_issues': 6,
#      'watchers': 31617,
#      'default_branch': 'main'}},
#    '_links': {'self': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734'},
#     'html': {'href': 'https://github.com/DataTalksClub/data-engineering-zoomcamp/pull/734'},
#     'issue': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734'},
#     'comments': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues/734/comments'},
#     'review_comments': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/comments'},
#     'review_comment': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/comments{/number}'},
#     'commits': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/pulls/734/commits'},
#     'statuses': {'href': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/statuses/6e3cb4be79b9de473d0e5ebaf2f7e8f2dedad90f'}},
#    'author_association': 'NONE',
#    'auto_merge': None,
#    'active_lock_reason': None,
#    'merged': False,
#    'mergeable': None,
#    'rebaseable': None,
#    'mergeable_state': 'unknown',
#    'merged_by': None,
#    'comments': 0,
#    'review_comments': 0,
#    'maintainer_can_modify': True,
#    'commits': 2,
#    'additions': 143,
#    'deletions': 1,
#    'changed_files': 2}},
#  'public': True,
#  'created_at': '2025-07-02T04:04:13Z',
#  'org': {'id': 72699292,
#   'login': 'DataTalksClub',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/orgs/DataTalksClub',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}

# %%
def process_event(event):
  result = {}

  result['id'] = event['id']
  result['type'] = event['type']
  result['public'] = event['public']
  result['created_at'] = event['created_at']

  result['actor__id'] = event['actor']['id']
  result['actor__login'] = event['actor']['login']

  return result

# %%
processed_events = []

for event in events_page:
  processed_event = process_event(event)
  processed_events.append(processed_event)

processed_events
# Out:
# [{'id': '51586324900',
#   'type': 'PullRequestEvent',
#   'public': True,
#   'created_at': '2025-07-02T04:04:13Z',
#   'actor__id': 206166622,
#   'actor__login': 'chaiandmushrooms'},
#  {'id': '51586034442',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-02T03:51:53Z',
#   'actor__id': 74387989,
#   'actor__login': 'marcosetm'},
#  {'id': '51584237360',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-02T02:28:26Z',
#   'actor__id': 46380150,
#   'actor__login': 'rdhwiya'},
#  {'id': '51584123999',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-02T02:23:04Z',
#   'actor__id': 15181448,
#   'actor__login': 'jickingbackup'},
#  {'id': '51583055421',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-02T01:32:40Z',
#   'actor__id': 29785251,
#   'actor__login': 'bmall0323'},
#  {'id': '51583045809',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-02T01:32:21Z',
#   'actor__id': 91744159,
#   'actor__login': 'edilaine-as'},
#  {'id': '51581229625',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-02T00:02:54Z',
#   'actor__id': 58479472,
#   'actor__login': 'emaoumaima'},
#  {'id': '51581081260',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T23:55:58Z',
#   'actor__id': 123568508,
#   'actor__login': 'imarcowenzel'},
#  {'id': '51579972343',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T23:00:45Z',
#   'actor__id': 116498093,
#   'actor__login': 'michael4686'},
#  {'id': '51577629887',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T21:26:11Z',
#   'actor__id': 194853171,
#   'actor__login': 'jno758'},
#  {'id': '51575986062',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-01T20:33:51Z',
#   'actor__id': 66178061,
#   'actor__login': 'danielhuang-3000'},
#  {'id': '51573178352',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T19:08:29Z',
#   'actor__id': 48856484,
#   'actor__login': 'Drake0306'},
#  {'id': '51573015027',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T19:03:41Z',
#   'actor__id': 55998334,
#   'actor__login': 'evandroase'},
#  {'id': '51572280958',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T18:42:58Z',
#   'actor__id': 178728479,
#   'actor__login': 'juanfeijoo98'},
#  {'id': '51571608775',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T18:24:02Z',
#   'actor__id': 128739164,
#   'actor__login': 'Sangitaswain'},
#  {'id': '51571140875',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T18:10:53Z',
#   'actor__id': 143434842,
#   'actor__login': 'KarinaAbi'},
#  {'id': '51568636867',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T17:02:54Z',
#   'actor__id': 167180684,
#   'actor__login': 'AhmedNasr78'},
#  {'id': '51567917458',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T16:43:59Z',
#   'actor__id': 56842521,
#   'actor__login': 'raghunandan-r'},
#  {'id': '51567825767',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T16:41:33Z',
#   'actor__id': 88222376,
#   'actor__login': 'carlos-carrillo01'},
#  {'id': '51566864430',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T16:16:26Z',
#   'actor__id': 152434498,
#   'actor__login': 'davidarmstrongmoody'},
#  {'id': '51565853861',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-01T15:52:58Z',
#   'actor__id': 41262116,
#   'actor__login': 'anukriti-kulshrestha'},
#  {'id': '51564153103',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-01T15:15:37Z',
#   'actor__id': 193060242,
#   'actor__login': 'AnassamzilUE'},
#  {'id': '51562759595',
#   'type': 'ForkEvent',
#   'public': True,
#   'created_at': '2025-07-01T14:47:08Z',
#   'actor__id': 206166622,
#   'actor__login': 'chaiandmushrooms'},
#  {'id': '51558379325',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T13:24:43Z',
#   'actor__id': 181355935,
#   'actor__login': 'ramm14'},
#  {'id': '51557019247',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T12:58:28Z',
#   'actor__id': 218780560,
#   'actor__login': 'genius-mushroom'},
#  {'id': '51546749269',
#   'type': 'WatchEvent',
#   'public': True,
#   'created_at': '2025-07-01T09:21:20Z',
#   'actor__id': 166155895,
#   'actor__login': 'yajeddig'}]

# %% [markdown]
# 2️⃣ **Convert timestamps:**
#    - Originally, timestamps might have been stored as ISO datetime strings:
#      ```json
#      "created_at": "2024-06-12T14:28:46Z"
#      ```
#      You can store them as they are, but in some cases, you may need to **convert** them to timestamps.
#    - Now, they are **formatted as Unix timestamp**:
#      ```json
#      "created_at": "1718202526"
#      ```

# %%
from datetime import datetime

def process_event(event):
  result = {}

  result['id'] = event['id']
  result['type'] = event['type']
  result['public'] = event['public']

  parsed_timestamp = datetime.fromisoformat(event['created_at'])
  result['created_at'] = parsed_timestamp.timestamp()

  result['actor__id'] = event['actor']['id']
  result['actor__login'] = event['actor']['login']

  return result


process_event(event)
# Out:
# {'id': '51546749269',
#  'type': 'WatchEvent',
#  'public': True,
#  'created_at': 1751361680.0,
#  'actor__id': 166155895,
#  'actor__login': 'yajeddig'}

# %% [markdown]
# 3️⃣ **Unnest lists:**
#    - The original structure might include a nested list:
#      ```json
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['data-engineering', 'dbt', 'docker', 'kafka', 'kestra', 'spark'],
#       'visibility': 'public',
#       'forks': 6093,
#      ```
#    - Since lists **cannot be stored directly in a database table**, they were likely **moved to a separate table**.

# %%
from datetime import datetime
# datetime.fromisoformat timestamp()

def process_event(event):
  result = {}

  result['id'] = event['id']
  result['type'] = event['type']
  result['public'] = event['public']

  parsed_timestamp = datetime.fromisoformat(event['created_at'])
  result['created_at'] = parsed_timestamp.timestamp()

  result['actor__id'] = event['actor']['id']
  result['actor__login'] = event['actor']['login']

  return result

process_event(event)
# Out:
# {'id': '51546749269',
#  'type': 'WatchEvent',
#  'public': True,
#  'created_at': 1751361680.0,
#  'actor__id': 166155895,
#  'actor__login': 'yajeddig'}

# %%
all_data = []

pages = events_getter()

for page in pages:
  all_data.extend(page)

len(all_data)
# Out:
# 296

# %%
def process_event(event):
  result = {}

  result['id'] = event['id']
  result['type'] = event['type']
  result['public'] = event['public']

  parsed_timestamp = datetime.fromisoformat(event['created_at'])
  result['created_at'] = parsed_timestamp.timestamp()

  result['actor__id'] = event['actor']['id']
  result['actor__login'] = event['actor']['login']

  topics = event.get('payload', {}).get('pull_request', {}).get('base', {}).get('repo', {}).get('topics', [])

  processed_topics = []
  for topic in topics:
    processed_topic = {
        'event_id': event['id'],
        'topic_name': topic
    }
    processed_topics.append(processed_topic)

  return result, processed_topics

# %%
processed_events = []
processed_topics = []

for event in all_data:
  processed_event, topics = process_event(event)
  processed_events.append(processed_event)
  processed_topics.extend(topics)

print(processed_events[:5])
print(processed_topics[:5])
# Out:
# [{'id': '52054879166', 'type': 'WatchEvent', 'public': True, 'created_at': 1752495955.0, 'actor__id': 212767187, 'actor__login': 'reyaleman-tech'}, {'id': '52051650046', 'type': 'ForkEvent', 'public': True, 'created_at': 1752491421.0, 'actor__id': 91944358, 'actor__login': 'qkrwnscjf'}, {'id': '52050279855', 'type': 'WatchEvent', 'public': True, 'created_at': 1752489484.0, 'actor__id': 216563235, 'actor__login': 'stewart-h13'}, {'id': '52046949622', 'type': 'WatchEvent', 'public': True, 'created_at': 1752485009.0, 'actor__id': 141754322, 'actor__login': 'Vital-Ahishakiye'}, {'id': '52040127738', 'type': 'WatchEvent', 'public': True, 'created_at': 1752475068.0, 'actor__id': 173776489, 'actor__login': 'Kaelthas200'}]
# [{'event_id': '51586324900', 'topic_name': 'data-engineering'}, {'event_id': '51586324900', 'topic_name': 'dbt'}, {'event_id': '51586324900', 'topic_name': 'docker'}, {'event_id': '51586324900', 'topic_name': 'kafka'}, {'event_id': '51586324900', 'topic_name': 'kestra'}]

# %% [markdown]
# ### **Example: Loading data into database**
#
#
# `watch_events` → Stores WatchEvent data
#
# `pull_request_events` → Stores PullRequestEvent data

# %%
import duckdb

# 1. Create a connection to a DuckDB database
conn = duckdb.connect("github_events.db")


# 2. Create the `github_events` Table
conn.execute("""
CREATE TABLE IF NOT EXISTS github_events (
    id TEXT PRIMARY KEY,
    type TEXT,
    public BOOLEAN,
    created_at DOUBLE,
    actor__id BIGINT,
    actor__login TEXT
);
""")

flattened_data = [
    (
        record["id"],
        record["type"],
        record["public"],
        record["created_at"],
        record["actor__id"],
        record["actor__login"]
    )
    for record in processed_events
]

# 3. Insert Data into the `github_events` Table
conn.executemany("""
INSERT INTO github_events (id, type, public, created_at, actor__id, actor__login)
VALUES (?, ?, ?, ?, ?, ?)
ON CONFLICT (id) DO NOTHING;
""", flattened_data)

print("Data successfully loaded into DuckDB!")


# Query and Print Data
df = conn.execute("SELECT * FROM github_events").df()

conn.close()

print("\nGitHub Events Data:")
df
# Out:
# Data successfully loaded into DuckDB!
#
# GitHub Events Data:
#               id        type  public    created_at  actor__id  \
# 0    52054879166  WatchEvent    True  1.752496e+09  212767187
# 1    52051650046   ForkEvent    True  1.752491e+09   91944358
# 2    52050279855  WatchEvent    True  1.752489e+09  216563235
# 3    52046949622  WatchEvent    True  1.752485e+09  141754322
# 4    52040127738  WatchEvent    True  1.752475e+09  173776489
# ..           ...         ...     ...           ...        ...
# 291  51564153103   ForkEvent    True  1.751383e+09  193060242
# 292  51562759595   ForkEvent    True  1.751381e+09  206166622
# 293  51558379325  WatchEvent    True  1.751376e+09  181355935
# 294  51557019247  WatchEvent    True  1.751375e+09  218780560
# 295  51546749269  WatchEvent    True  1.751362e+09  166155895
#
#          actor__login
# 0      reyaleman-tech
# 1           qkrwnscjf
# 2         stewart-h13
# 3    Vital-Ahishakiye
# 4         Kaelthas200
# ..                ...
# 291      AnassamzilUE
# 292  chaiandmushrooms
# 293            ramm14
# 294   genius-mushroom
# 295          yajeddig
#
# [296 rows x 6 columns]

# %% [markdown]
# Problems:
#
# ❌ **Schema management is manual** – If the schema changes, you need to update table structures manually.
# ❌ **No automatic retries** – If the network fails, data may be lost.
# ❌ **No incremental loading** – Every run reloads everything, making it slow and expensive.
# ❌ **More code to maintain** – A simple pipeline quickly becomes complex.

# %%
def process_event(event):
  result = {}

  result['id'] = event['id']
  result['type'] = event['type']
  result['public'] = event['public']

  parsed_timestamp = datetime.fromisoformat(event['created_at'])
  result['created_at'] = parsed_timestamp.timestamp()

  result['actor__id'] = event['actor']['id']
  result['actor__login'] = event['actor']['login']

  result['repo__id'] = event['repo']['id']

  topics = event.get('payload', {}).get('pull_request', {}).get('base', {}).get('repo', {}).get('topics', [])

  processed_topics = []
  for topic in topics:
    processed_topic = {
        'event_id': event['id'],
        'topic_name': topic
    }
    processed_topics.append(processed_topic)

  return result, processed_topics

# %%
processed_events = []
processed_topics = []

for event in all_data:
  processed_event, topics = process_event(event)
  processed_events.append(processed_event)
  processed_topics.extend(topics)

print(processed_events[:5])
print(processed_topics[:5])
# Out:
# [{'id': '52054879166', 'type': 'WatchEvent', 'public': True, 'created_at': 1752495955.0, 'actor__id': 212767187, 'actor__login': 'reyaleman-tech', 'repo__id': 419661684}, {'id': '52051650046', 'type': 'ForkEvent', 'public': True, 'created_at': 1752491421.0, 'actor__id': 91944358, 'actor__login': 'qkrwnscjf', 'repo__id': 419661684}, {'id': '52050279855', 'type': 'WatchEvent', 'public': True, 'created_at': 1752489484.0, 'actor__id': 216563235, 'actor__login': 'stewart-h13', 'repo__id': 419661684}, {'id': '52046949622', 'type': 'WatchEvent', 'public': True, 'created_at': 1752485009.0, 'actor__id': 141754322, 'actor__login': 'Vital-Ahishakiye', 'repo__id': 419661684}, {'id': '52040127738', 'type': 'WatchEvent', 'public': True, 'created_at': 1752475068.0, 'actor__id': 173776489, 'actor__login': 'Kaelthas200', 'repo__id': 419661684}]
# [{'event_id': '51586324900', 'topic_name': 'data-engineering'}, {'event_id': '51586324900', 'topic_name': 'dbt'}, {'event_id': '51586324900', 'topic_name': 'docker'}, {'event_id': '51586324900', 'topic_name': 'kafka'}, {'event_id': '51586324900', 'topic_name': 'kestra'}]

# %%
import duckdb

# 1. Create a connection to DuckDB
conn = duckdb.connect("github_events.db")


# 2. Fetch current table schema
current_columns = {row[1] for row in conn.execute("PRAGMA table_info(github_events)").fetchall()}
print(current_columns)

# 3. Detect and add new columns dynamically
for record in processed_events:
    for key in record.keys():
        if key not in current_columns:
            col_type = "TEXT"  # Default type
            if isinstance(record[key], bool):
                col_type = "BOOLEAN"
            elif isinstance(record[key], int):
                col_type = "BIGINT"
            elif isinstance(record[key], float):
                col_type = "DOUBLE"
            print(f"ALTER TABLE github_events ADD COLUMN {key} {col_type};")
            alter_query = f"ALTER TABLE github_events ADD COLUMN {key} {col_type};"
            conn.execute(alter_query)
            print(f"Added new column: {key} ({col_type})")
            current_columns.add(key)  # Update schema tracking

# 4. Prepare data for insertion (handle missing fields)
columns = sorted(current_columns)  # Maintain consistent order
flattened_data = [
    tuple(record.get(col, None) for col in columns)  # Fill missing values with NULL
    for record in processed_events
]

# 5. Construct dynamic SQL for insertion
placeholders = ", ".join(["?" for _ in columns])
columns_str = ", ".join(columns)

insert_query = f"""
INSERT INTO github_events ({columns_str})
VALUES ({placeholders})
ON CONFLICT (id) DO UPDATE SET {", ".join(f"{col}=excluded.{col}" for col in columns if col != "id")};
"""

# 6. Insert data into DuckDB
conn.executemany(insert_query, flattened_data)
print("Data successfully loaded into DuckDB with schema updates!")

# 7. Query the table
df = conn.execute("""SELECT * FROM github_events""").df()

conn.close()

print("\nGitHub Events Data:")
df
# Out:
# {'id', 'actor__login', 'created_at', 'type', 'public', 'actor__id'}
# ALTER TABLE github_events ADD COLUMN repo__id BIGINT;
# Added new column: repo__id (BIGINT)
# Data successfully loaded into DuckDB with schema updates!
#
# GitHub Events Data:
#               id        type  public    created_at  actor__id  \
# 0    52054879166  WatchEvent    True  1.752496e+09  212767187
# 1    52051650046   ForkEvent    True  1.752491e+09   91944358
# 2    52050279855  WatchEvent    True  1.752489e+09  216563235
# 3    52046949622  WatchEvent    True  1.752485e+09  141754322
# 4    52040127738  WatchEvent    True  1.752475e+09  173776489
# ..           ...         ...     ...           ...        ...
# 291  51564153103   ForkEvent    True  1.751383e+09  193060242
# 292  51562759595   ForkEvent    True  1.751381e+09  206166622
# 293  51558379325  WatchEvent    True  1.751376e+09  181355935
# 294  51557019247  WatchEvent    True  1.751375e+09  218780560
# 295  51546749269  WatchEvent    True  1.751362e+09  166155895
#
#          actor__login   repo__id
# 0      reyaleman-tech  419661684
# 1           qkrwnscjf  419661684
# 2         stewart-h13  419661684
# 3    Vital-Ahishakiye  419661684
# 4         Kaelthas200  419661684
# ..                ...        ...
# 291      AnassamzilUE  419661684
# 292  chaiandmushrooms  419661684
# 293            ramm14  419661684
# 294   genius-mushroom  419661684
# 295          yajeddig  419661684
#
# [296 rows x 7 columns]

# %% [markdown]
# #### **What’s happening here?**
# | Step | Action |
# |----------|-------------|
# | 🛠 **1** | Connects to DuckDB |
# | 📜 **2** | Fetches current schema from DuckDB |
# | 🏗 **3** | Detects and **adds new columns dynamically** |
# | 🔄 **4** | Fills missing values with `NULL` to ensure smooth inserts |
# | 📌 **5** | Dynamically constructs an **INSERT or UPDATE (`UPSERT`)** query |
# | 📝 **6** | Inserts new data while updating existing records |
# | 📊 **7** | Queries the data |
#
# ---
